# %% [markdown]
# <a href="https://colab.research.google.com/github/TLJ5258/Lab2/blob/main/TyJacksonPetShop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Lab 2 - Pet Shop

# %% [markdown]
# **Description:**

# %% [markdown]
# Below is an entity relationship diagram, showing the relationship between entities and the processes that take place within the pet shop. I designed the diagram based more around the customer rather than what they purchase or do (like taking part in a rewards program). The customer has the most relationships compared to all other entities, so that entity was placed closer to the center. The other entities were placed from left to right, then downwards, through the purchasing process.

# %% [markdown]
# **Diagram:**

# %% [markdown]
# ![PetShopERD.JPG](data:image/jpeg;base64,...)
